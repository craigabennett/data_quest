# %%
import pandas as pd
import numpy as np

https://github.com/guipsamora/pandas_exercises/tree/master/01_Getting_%26_Knowing_Your_Data/Chipotle

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.index.max()
# Out:
# 4621

# %%
chipo['item_price'] = chipo['item_price'].str.replace("$"," ").astype(float)

# %%
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
col = len(chipo.columns)
col
# Out:
# 5

# %%
print(list(chipo.columns))
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
chipo.pivot_table(values = ['quantity','item_price'],index=['item_name'], 
aggfunc = np.sum).sort_values(by='quantity', ascending=False)
# Out:
#                                        item_price  quantity
# item_name
# Chicken Bowl                              7342.73       761
# Chicken Burrito                           5575.82       591
# Chips and Guacamole                       2201.04       506
# Steak Burrito                             3851.43       386
# Canned Soft Drink                          438.75       351
# Chips                                      494.34       230
# Steak Bowl                                2260.19       221
# Bottled Water                              302.56       211
# Chips and Fresh Tomato Salsa               361.36       130
# Canned Soda                                137.34       126
# Chicken Salad Bowl                        1228.75       123
# Chicken Soft Tacos                        1108.09       120
# Side of Chips                              185.90       110
# Veggie Burrito                             934.77        97
# ...

# %%
# for the most ordered item = 761 
# Chicken bowl 
#diet coke was most ordered item in choice description , 159 
#Items ordered in total 4972

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %%
#revenue for the period 

Rev = chipo['item_price']*chipo['quantity']

np.round((Rev.sum()),2)
# Out:
# 39237.019999999997

# %%
# Average order size 

Rev.mean()
Rev.sum()/order
# Out:
# 21.3942311886587

# %%
# of Unique Orders 
Combined = chipo['item_name']+ chipo['choice_description']
Combined.nunique()
# Out:
# 1859

# %%
# of Orders Made 
order = chipo['order_id'].nunique()
order
# Out:
# 1834

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.6+ KB

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
c=  chipo.groupby('item_name').sum()
#c = c.sum()
#c = c.sort_values(['quantity'], ascending=False)
c
# Out:
#                                        order_id  quantity  item_price  revenue
# item_name
# 6 Pack Soft Drink                         52322        55      356.95   369.93
# Barbacoa Bowl                             53972        66      672.36   672.36
# Barbacoa Burrito                          74718        91      894.75   894.75
# Barbacoa Crispy Tacos                      5613        12      120.21   138.71
# Barbacoa Salad Bowl                        9708        10      106.40   106.40
# Barbacoa Soft Tacos                       18725        25      250.46   250.46
# Bottled Water                            175944       211      302.56   649.18
# Bowl                                        472         4       29.60    74.00
# Burrito                                    1550         6       44.40    44.40
# Canned Soda                               76396       126      137.34   191.84
# Canned Soft Drink                        304753       351      438.75   603.75
# ...

# %%
r = chipo['revenue'] = chipo['quantity'] * chipo['item_price']
r.sum()
# Out:
# 39237.020000000055

# %%
o = order_grouped = chipo.groupby(by=['order_id']).sum()
o
# Out:
#           quantity  item_price  revenue
# order_id
# 1                4       11.56    11.56
# 2                2       16.98    33.96
# 3                2       12.67    12.67
# 4                2       21.00    21.00
# 5                2       13.70    13.70
# 6                2       17.50    17.50
# 7                2       15.70    15.70
# 8                2       10.88    10.88
# 9                3       10.67    12.85
# 10               2       13.20    13.20
# 11               2       12.38    12.38
# 12               2       14.37    14.37
# 13               2       10.88    10.88
# 14               2       10.08    10.08
# 15               2       10.88    10.88
# 16               2       10.68    10.68
# 17               2       10.08    10.08
# 18               4       24.90    24.90
# 19               2       13.90    13.90
# 20               4       36.20    36.20
# 21               3       23.36    23.36
# 22               2       12.98    12.98
# ...

# %%
chipo['item_name'].unique()[0:10][-2:]
# Out:
# array(['Chips and Guacamole', 'Chicken Crispy Tacos'], dtype=object)
